# %%
# importar bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# Leitura data set
df = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\ibodonto\vendas_ibodonto_asb.csv", encoding="utf-8", sep=';')

# %%
df
# Out:
#      idVenda        Data Venda    Hora Venda    Data Pagamento  \
# 0     445952  20/06/2022 00:24  00:24:46:917               NaN
# 1     445189  17/06/2022 14:54  14:54:00:513  18/06/2022 00:00
# 2     443894  15/06/2022 15:42  15:42:45:147  22/06/2022 00:00
# 3     443882  15/06/2022 15:20  15:20:06:397  23/06/2022 00:00
# 4     440736  13/06/2022 10:00  10:00:46:510  14/06/2022 00:00
# ..       ...               ...           ...               ...
# 374    66442  15/03/2019 16:54  16:54:29:310               NaN
# 375    66404  12/03/2019 10:12  10:12:39:583  13/03/2019 00:00
# 376    66308  07/03/2019 16:49  16:49:05:140  08/03/2019 00:00
# 377    66248  01/03/2019 09:03  09:03:12:750  14/03/2019 00:00
# 378    65732  26/02/2019 15:20  15:20:43:690               NaN
#
#                  Situa??o  Data Alerta  Qte Itens Valor Comprado  \
# 0    Aguardando Pagamento          NaN          1           3176
# 1                    Pago          NaN          1           3176
# ...

# %%
# Tratamento dos dados

# %%
# Dicionário de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   idVenda         379 non-null    int64
#  1   Data Venda      379 non-null    object
#  2   Hora Venda      379 non-null    object
#  3   Data Pagamento  224 non-null    object
#  4   Situa??o        379 non-null    object
#  5   Data Alerta     0 non-null      float64
#  6   Qte Itens       379 non-null    int64
#  7   Valor Comprado  379 non-null    object
#  8   Nome Cliente    379 non-null    object
#  9   Email Cliente   379 non-null    object
#  10  CPF             379 non-null    object
#  11  RG              379 non-null    object
#  12  Telefone        101 non-null    object
#  13  Celular         368 non-null    object
#  14  Endere?o        379 non-null    object
#  15  N?mero          379 non-null    object
#  16  Complemento     171 non-null    object
# ...

# %%
# análise dos valores ausentes
df.isna().sum().sort_values(ascending=False)
# Out:
# Data Alerta       379
# Telefone          278
# Complemento       208
# Data Pagamento    155
# Celular            11
# idVenda             0
# Latitude            0
# UF                  0
# Cidade              0
# CEP                 0
# Bairro              0
# N?mero              0
# Endere?o            0
# RG                  0
# Data Venda          0
# CPF                 0
# Email Cliente       0
# Nome Cliente        0
# Valor Comprado      0
# Qte Itens           0
# Situa??o            0
# Hora Venda          0
# Longitude           0
# dtype: int64

# %%
# criar base somente com vendas efetuadas (com data de pagamento)
# Converte campo data pagamento para datetime
df['Data Pagamento'] = pd.to_datetime(df['Data Pagamento'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   idVenda         379 non-null    int64
#  1   Data Venda      379 non-null    object
#  2   Hora Venda      379 non-null    object
#  3   Data Pagamento  224 non-null    datetime64[ns]
#  4   Situa??o        379 non-null    object
#  5   Data Alerta     0 non-null      float64
#  6   Qte Itens       379 non-null    int64
#  7   Valor Comprado  379 non-null    object
#  8   Nome Cliente    379 non-null    object
#  9   Email Cliente   379 non-null    object
#  10  CPF             379 non-null    object
#  11  RG              379 non-null    object
#  12  Telefone        101 non-null    object
#  13  Celular         368 non-null    object
#  14  Endere?o        379 non-null    object
#  15  N?mero          379 non-null    object
#  16  Complemento     171 non-null    object
# ...

# %%
# cria data set somente com data de pagamento
df_pag = df.dropna(subset=['Data Pagamento'])

# %%
df_pag
# Out:
#      idVenda        Data Venda    Hora Venda Data Pagamento Situa??o  \
# 1     445189  17/06/2022 14:54  14:54:00:513     2022-06-18     Pago
# 2     443894  15/06/2022 15:42  15:42:45:147     2022-06-22     Pago
# 3     443882  15/06/2022 15:20  15:20:06:397     2022-06-23     Pago
# 4     440736  13/06/2022 10:00  10:00:46:510     2022-06-14     Pago
# 6     436081  07/06/2022 14:14  14:14:34:017     2022-10-06     Pago
# ..       ...               ...           ...            ...      ...
# 371    68699  05/04/2019 17:41  17:41:06:677     2019-10-04     Pago
# 373    67845  19/03/2019 18:15  18:15:34:483     2019-03-20     Pago
# 375    66404  12/03/2019 10:12  10:12:39:583     2019-03-13     Pago
# 376    66308  07/03/2019 16:49  16:49:05:140     2019-08-03     Pago
# 377    66248  01/03/2019 09:03  09:03:12:750     2019-03-14     Pago
#
#      Data Alerta  Qte Itens Valor Comprado                     Nome Cliente  \
# ...

# %%
# tipos de análise com data
from datetime import date

# sofisticadas
# qual dias das semana as vendas são maiores, quais horários
